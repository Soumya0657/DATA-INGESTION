# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya0657/DATA-INGESTION/blob/https%2Fmybinder.org%2Fv2%2Fgh%2Fjupyterlab%2Fjupyterlab-demo%2F79184a07d47cf03787b39cfc345da98794d76554urlpath%3Dlab%252Ftree%252Fdemo%252Ftask1ML.ipynb/DATA_INGESTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load data from CSV
df = pd.read_csv('data.csv')
print(df.head())

# %%
import requests
import pandas as pd

response = requests.get("https://api.example.com/data")
data = response.json()
df = pd.DataFrame(data)
print(df.head())

# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='your_password',
    database='your_db'
)

query = "SELECT * FROM your_table"
df = pd.read_sql(query, conn)
conn.close()

print(df.head())

# %%
df = pd.read_excel('data.xlsx', sheet_name='Sheet1')
print(df.head())

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://example.com"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

data = []
for row in soup.select('table tr'):
    cols = [col.text.strip() for col in row.select('td')]
    if cols:
        data.append(cols)

df = pd.DataFrame(data, columns=["Col1", "Col2", "Col3"])
print(df.head())

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:your_password@localhost/your_db')
df.to_sql(name='your_table', con=engine, index=False, if_exists='append')
