# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya0657/DATA-INGESTION/blob/https%2Fmybinder.org%2Fv2%2Fgh%2Fjupyterlab%2Fjupyterlab-demo%2F79184a07d47cf03787b39cfc345da98794d76554urlpath%3Dlab%252Ftree%252Fdemo%252Ftask1ML.ipynb/DATA_INGESTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import mysql.connector
from sqlalchemy import create_engine

#from CSV
df_csv = pd.read_csv('data.csv')
print(df_csv.head())

#from EXCEL
df_excel = pd.read_excel('data.xlsx', sheet_name='Sheet1')
print(df_excel.head())

#from API
response = requests.get('https://api.example.com/data')
data_json = response.json()
df_api = pd.DataFrame(data_json)
print(df_api.head())

#from Database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='yourpassword',
    database='yourdatabase'
)

query = "SELECT * FROM your_table"
df_sql = pd.read_sql(query, conn)
print(df_sql.head())
conn.close()

#clean the Data
# Example cleaning
df_csv.dropna(inplace=True)
df_csv.columns = [col.lower().replace(" ", "_") for col in df_csv.columns]

#into SQL
engine = create_engine("mysql+mysqlconnector://root:yourpassword@localhost/yourdatabase")
df_csv.to_sql('ingested_data', con=engine, if_exists='replace', index=False)
#validate data
df_check = pd.read_sql("SELECT COUNT(*) FROM ingested_data", con=engine)
print(df_check)

#combine mutiple sources
